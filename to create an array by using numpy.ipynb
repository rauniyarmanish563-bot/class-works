# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/class-works/blob/main/to%20create%20an%20array%20by%20using%20numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to create an array
#...................................
#variable = numpy.array(list_or_tuple)
import numpy as np
# To create array
numbers = np.array([20,30,40,70,90])
print(numbers)
# Out:
# [20 30 40 70 90]
