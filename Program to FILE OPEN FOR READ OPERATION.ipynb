# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/class-works/blob/main/Program%20to%20FILE%20OPEN%20FOR%20READ%20OPERATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FILE OPEN FOR READ OPERATION
filev = open("firstfile.txt","r")
# to check file is open or not
if(filev):
  data = filev.read()
  print(data)
  print("..................................")
  print("No. of characters :",len (data))
  # closing file
  filev.close()
else:
  print("Unable to open the file")
# Out:
# ABCDEFGHIJKLMNOPQRST
# ..................................
# No. of characters : 20
