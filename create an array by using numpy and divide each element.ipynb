# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/class-works/blob/main/create%20an%20array%20by%20using%20numpy%20and%20divide%20each%20element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# Creating array
data = np.array([45,56,89,90,29])
print(data)

# dividing each element by 5
numbers2 = data / 5
print("After dividing each element by 5 : ")
print(numbers2)
# Out:
# [45 56 89 90 29]
# After dividing each element by 5 :
# [ 9.  11.2 17.8 18.   5.8]
